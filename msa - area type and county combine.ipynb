# %%
import pandas as pd

# %%
msa_df = pd.read_excel (r'E:\MS_DAEN\DAEN690\Datasets\all_data_M_2021.xlsx')

# %%
msa_df

# %%
areadef_df = pd.read_excel (r'area_definitions_m2021.xlsx')

# %%
areadef_df.columns
# Out:
# Index(['FIPS code', 'State', 'State abbreviation', 'May 2021 MSA code ',
#        'May 2021 MSA name', 'County code', 'Township code',
#        'County name (or Township name for the New England states)'],
#       dtype='object')

# %%
areadef_df = areadef_df.astype (str)
areadef_df['May 2021 MSA code '] = areadef_df['May 2021 MSA code '].str.strip()

# %%
msa_df = msa_df.astype (str)

# %%
#combinedf=pd.merge(msa_df, areadef_df, on=('AREA','May 2021 MSA code'))
combinedf = pd.merge(msa_df, areadef_df, how='left', left_on=['PRIM_STATE','AREA'], right_on=['State abbreviation','May 2021 MSA code '])

# %%
combinedf.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY', 'FIPS code', 'State',
#        'State abbreviation', 'May 2021 MSA code ', 'May 2021 MSA name',
#        'County code', 'Township code',
#        'County name (or Township name for the New England states)'],
#       dtype='object')

# %%
combinedf_new = combinedf[['AREA', 'AREA_TITLE', 'AREA_TYPE','PRIM_STATE','State','State abbreviation', 'May 2021 MSA code ', 'May 2021 MSA name', 'County code', 'Township code','County name (or Township name for the New England states)']]

# %%
combinedf[combinedf.isna().any(axis=1)]
# Out:
#             AREA      AREA_TITLE AREA_TYPE PRIM_STATE NAICS     NAICS_TITLE  \
# 816570   6600001            Guam         6         GU     0  Cross-industry
# 816571   7800001  Virgin Islands         6         VI     0  Cross-industry
# 819587   6600001            Guam         6         GU     0  Cross-industry
# 819600   7800001  Virgin Islands         6         VI     0  Cross-industry
# 822421   6600001            Guam         6         GU     0  Cross-industry
# ...          ...             ...       ...        ...   ...             ...
# 1914915  7800001  Virgin Islands         6         VI     0  Cross-industry
# 1917931  6600001            Guam         6         GU     0  Cross-industry
# 1917944  7800001  Virgin Islands         6         VI     0  Cross-industry
# 1921926  6600001            Guam         6         GU     0  Cross-industry
# 1922789  6600001            Guam         6         GU     0  Cross-industry
#
#                 I_GROUP OWN_CODE OCC_CODE  \
# ...

# %%
combinedf_new.to_csv(r'msa_county.csv')
